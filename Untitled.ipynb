# %% [markdown]
# ## IMPORTING REQUIRED LIBRARIES

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %% [markdown]
# ## reading the ACW dataset using the CSV library

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\ACW data assignment_files'

# %%
file_path = "C:\\Users/DELL/Desktop/ACW data assignment_files/acw_user_data.csv"   #calling file path
dataset = pd.read_csv(file_path)  # read csv file.

# %% [markdown]
# ## Dataset overview

# %%
dataset.head(6)  # a view of the first 6 rows and their columns.
# Out:
#               Address Street       Address City Address Postcode  Age (Years)  \
# 0              70 Lydia isle         Lake Conor          S71 7XZ           89
# 1           00 Wheeler wells         Chapmanton           L2 7BT           46
# 2       Studio 33K Joel walk     Randallborough         ME3N 1GH           22
# 3  Studio 46S Bethany lights         East Reece          E10 9RJ           56
# 4     Flat 3 Christine views       Fletcherstad          WS2 9SN           57
# 5     Studio 43M Emily rapid  West Derekborough          W1J 0DL           23
#
#    Distance Commuted to Work (Km)          Employer Company  \
# 0                            0.00                       NaN
# 1                           13.72            Begum-Williams
# 2                           16.02               Hill-Wright
# 3                           19.35                 Green LLC
# 4                            5.94  Hill, Evans and Harrison
# ...

# %%
# DATASET BASIC INFORMATION
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Address Street                  1000 non-null   object
#  1   Address City                    1000 non-null   object
#  2   Address Postcode                1000 non-null   object
#  3   Age (Years)                     1000 non-null   int64
#  4   Distance Commuted to Work (Km)  1000 non-null   float64
#  5   Employer Company                754 non-null    object
#  6   Credit Card Start Date          1000 non-null   object
#  7   Credit Card Expiry Date         1000 non-null   object
#  8   Credit Card Number              1000 non-null   int64
#  9   Credit Card CVV                 1000 non-null   int64
#  10  Dependants                      981 non-null    float64
#  11  First Name                      1000 non-null   object
# ...

# %% [markdown]
# ### converting all required column with object datatype to a numeric datatype

# %%
dataset['Vehicle Type'] = pd.to_numeric(dataset["Vehicle Type"], errors = 'coerce', downcast ="integer")
dataset['Vehicle Model'] = pd.to_numeric(dataset["Vehicle Model"], errors = 'coerce', downcast ="integer")
dataset['Vehicle Make'] = pd.to_numeric(dataset["Vehicle Make"], errors = 'coerce', downcast ="integer")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Address Street                  1000 non-null   object
#  1   Address City                    1000 non-null   object
#  2   Address Postcode                1000 non-null   object
#  3   Age (Years)                     1000 non-null   int64
#  4   Distance Commuted to Work (Km)  1000 non-null   float64
#  5   Employer Company                754 non-null    object
#  6   Credit Card Start Date          1000 non-null   object
#  7   Credit Card Expiry Date         1000 non-null   object
#  8   Credit Card Number              1000 non-null   int64
#  9   Credit Card CVV                 1000 non-null   int64
#  10  Dependants                      981 non-null    float64
#  11  First Name                      1000 non-null   object
# ...

# %% [markdown]
# ## numerical column description since dataset doesnt have objective column

# %%
dataset.describe()
# Out:
#        Age (Years)  Distance Commuted to Work (Km)  Credit Card Number  \
# count  1000.000000                     1000.000000        1.000000e+03
# mean     54.302000                       10.457770        4.188020e+17
# std      21.319646                        6.951997        1.304208e+18
# min      18.000000                        0.000000        6.041600e+10
# 25%      36.000000                        5.637500        3.857314e+13
# 50%      54.000000                       12.170000        3.510666e+15
# 75%      72.000000                       16.262500        4.635909e+15
# max      91.000000                       20.340000        4.967327e+18
#
#        Credit Card CVV  Dependants  Yearly Pension (GBP)  Yearly Salary (GBP)  \
# count      1000.000000  981.000000           1000.000000          1000.000000
# mean        932.482000    2.135576           5875.413000         57814.078000
# std        1626.125269    0.977799          10986.507761         23270.417139
# ...

# %% [markdown]
# ## checking and replacing missing values

# %%
dataset.isna().sum()
# Out:
# Address Street                       0
# Address City                         0
# Address Postcode                     0
# Age (Years)                          0
# Distance Commuted to Work (Km)       0
# Employer Company                   246
# Credit Card Start Date               0
# Credit Card Expiry Date              0
# Credit Card Number                   0
# Credit Card CVV                      0
# Dependants                          19
# First Name                           0
# Bank IBAN                            0
# Last Name                            0
# Marital Status                       0
# Yearly Pension (GBP)                 0
# Retired                              0
# Yearly Salary (GBP)                  0
# Sex                                  0
# Vehicle Make                      1000
# Vehicle Model                      985
# Vehicle Year                         0
# Vehicle Type                      1000
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# Address Street                       0
# Address City                         0
# Address Postcode                     0
# Age (Years)                          0
# Distance Commuted to Work (Km)       0
# Employer Company                   246
# Credit Card Start Date               0
# Credit Card Expiry Date              0
# Credit Card Number                   0
# Credit Card CVV                      0
# Dependants                          19
# First Name                           0
# Bank IBAN                            0
# Last Name                            0
# Marital Status                       0
# Yearly Pension (GBP)                 0
# Retired                              0
# Yearly Salary (GBP)                  0
# Sex                                  0
# Vehicle Make                      1000
# Vehicle Model                      985
# Vehicle Year                         0
# Vehicle Type                      1000
# dtype: int64

# %% [markdown]
# ##  Replacing nan of dependant column and presenting problematic rows

# %%
df = pd.DataFrame(dataset)

# Get the indices of NaN values in 'dependants' inform of a list.
nan_indices = df[df['Dependants'].isna()].index.tolist()  

# Calculate the mean of the column
mean_value = df['Dependants'].mean()

# Replace NaN values in 'Dependants' with the mean
df['Dependants'].fillna(mean_value, inplace=True)

# Print the DataFrame after replacing NaN values
print("dataset:")
print(df)

# Print the indices of replaced NaN values
print("Indices of replaced NaN values:", nan_indices)

#print(nan_indices)
# Out:
# dataset:
#                 Address Street    Address City Address Postcode  Age (Years)  \
# 0                70 Lydia isle      Lake Conor          S71 7XZ           89
# 1             00 Wheeler wells      Chapmanton           L2 7BT           46
# 2         Studio 33K Joel walk  Randallborough         ME3N 1GH           22
# 3    Studio 46S Bethany lights      East Reece          E10 9RJ           56
# 4       Flat 3 Christine views    Fletcherstad          WS2 9SN           57
# ..                         ...             ...              ...          ...
# 995   Studio 6 Heather prairie    North Amelia           E9 0HB           48
# 996          Flat 3 Davies run      Greenshire           E7 4UJ           22
# 997     Flat 7 Barber motorway    Burrowsshire          L62 8TA           38
# 998              00 Tony forks       Abbiebury          NP4 1JL           45
# 999       Flat 9 Mohamed route       West Glen         LL3M 4WS           80
#
# ...

# %% [markdown]
# ## saving the processed.json file of the list in a jason format.

# %% [markdown]
# ## CONVERTING FLAT STRUCTURES TO THEIR RESPECTIVE NESTED STRUCTURES

# %% [markdown]
# ### 2. CREATE A DATA STRUCTURE FOR NESTING

# %% [markdown]
# ## STEPS
# ### 1. IDENTIFY THE HEIRACHY OF THE STRUCTURE
#
# a. Vehicle - consists of make, model, year, and type
#
# b. Credit Card - consists of start date, end date, number, security code, and IBAN.
#
# c. Address - consists of the main address, city, and postcode.

# %%
nested_data = {}
#THIS IS A DATA STRUCTURE THAT REPRESENTS THE NESTED RELATIONSHIP.

# %%
### ITERATE OVER THE FLAT DATA:
for row in dataset:
    vehicle_make = row["Vevicle Make"]
    vehicle_model = row["Vehicle Mode"]
    vehicle_year = row["Vehicle Year"]
    vehicle_Type = row['Vehicle Type']
    
    if vehicle_Type is None:
        
        nested_data[vehicle_Type] = {'vehicle_Make': row['vehicle Make'], 'vehicle_model' : row["Vehicle Mode"], 'vehicle_year' : row["Vehicle Year"]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-142456f8a7d9> in <module>
#       1 ### ITERATE OVER THE FLAT DATA:
#       2 for row in dataset:
# ----> 3     vehicle_make = row["Vevicle Make"]
#       4     vehicle_model = row["Vehicle Mode"]
#       5     vehicle_year = row["Vehicle Year"]
#
# TypeError: string indices must be integers

# %%
import os

# Specify the directory where you want to save the JSON file
directory = '/path/to/your/directory'

# Specify the filename for the JSON file
filename = 'output.json'

# Combine the directory and filename to create the full file path
json_file_path = os.path.join(directory, filename)

# Print the resulting JSON file path
print(f'The JSON file will be saved at: {json_file_path}')
